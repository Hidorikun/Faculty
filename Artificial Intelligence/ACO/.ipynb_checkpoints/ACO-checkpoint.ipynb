# %%
from random import * 
from copy import deepcopy

# %%
class UndirectedGraph:
    def __init__(self):
        self.edges = {}
        self.pheromones = {}
        
    def add_pheromones(self, x,  y, ph):
        self.pheromones[(x, y)] += ph
        self.pheromones[(y, x)] += ph
        
    def add_edge(self, x, y):
        if not x in self.edges.keys():
            self.edges[x] = [y]
        else:
            self.edges[x].append(y)
        
        if not y in self.edges.keys():
            self.edges[y] = [x]
        else:
            self.edges[y].append(x)
            
        self.pheromones[(x, y)] = 0
        self.pheromones[(y, x)] = 0
    
    def nr_of_vertices():
        return len(self.edges.keys())
    
    def get_pheromones(self, x, y):
        return self.pheromones[(x, y)]; 
    
    def get_neighbours(self, x):
        return self.edges[x]
    
    def decrease_pheromones_on_all_edges(self, coef):
        for edge in self.pheromones.keys():
            self.pheromones[edge] -= coef

    def __str__(self):
        return str(self.pheromones)

# %%
class Ant:
    def __init__(self):
        self.solution = []
    
    def fitness(self, problem):
        # defined as the difference between the numbere of correct words and guessed words

        sol = self.solution + problem.get_column_words(self.solution)
        
        return len([word for word in problem.words if word not in sol])
    
    def update(self, x):
        self.solution.append(x)
        
    def __str__(self):
        return str(self.solution)

# %%
class Problem:
    def __init__(self, file_name):
        self.load_data(file_name)

    def load_data(self, file_name):
        with open(file_name, 'r') as f:
            self.words = [line.strip(" ").strip("\n") for line in f]
            self.n = len(self.words)
            self.words = self.words + self.get_column_words(self.words)
            self.graph = UndirectedGraph()
            for i in range(len(self.words) - 1):
                for j in range(i + 1, len(self.words)):
                    self.graph.add_edge(self.words[i], self.words[j])
            
    def get_column_words(self, words):
        return [ "".join([ words[row][col]  for row in range(len(words))])for col in range(len(words[0]))]

# %%
class Controller:
    def __init__(self, data_file_path, params_file_path):
        self.problem = Problem(data_file_path)
        self.no_runs = 0 
        self.no_genes = 0
        self.local_pheromone_increase = 0
        self.global_pheromone_increase = 0
        self.evaporation_coefficient = 0
        self.probability_for_best = 0
        self.load_parameters(params_file_path)
        self.population = []
        self.no_steps = len(self.problem.words) // 2 - 1
        self.graph = deepcopy(self.problem.graph)
        
    def iteration(self):
        for word in self.problem.words:
            ant = Ant()
            ant.update(word)
            self.population.append(ant)
            
        for step in range(self.no_steps):
            for i, ant in enumerate(self.population):
                current_word = ant.solution[step]
                neighbours = self.get_neighbours(ant, current_word)
                
#                 print("ant {}".format(i))
#                 print("solution: {}".format(ant))
#                 print("neighbours: {}".format(neighbours))
                
                if (random() < self.probability_for_best):
                    next_word = self.get_best_neighbour(neighbours, current_word)
#                     print("I am choosing the best")
                else:
                    next_word = choice(self.graph.get_neighbours(current_word))
#                     print("I am choosing randomly")
#                 print("my choice is {}".format(next_word))
                ant.update(next_word)

    
        best_ant = self.get_best_ant()

        if best_ant != None:
            self.spread_pheromones(best_ant)
        
    def spread_pheromones(self, ant):
        x = ant.solution[0]
        for y in ant.solution[1:]:
            self.graph.add_pheromones(x, y, self.local_pheromone_increase)
            x = y 
            
    def get_neighbours(self, ant, current_word):
        neighbours = deepcopy(self.graph.get_neighbours(current_word))
        neighbours = [ neighbour for neighbour in neighbours if neighbour not in ant.solution]
        if len(neighbours) == 0:
            return deepcopy(self.graph.get_neighbours(current_word)) 
        
        return neighbours

    def get_best_ant(self):
        population = sorted(self.population, key = lambda ant: ant.fitness(self.problem))
        if (population[0] != population[1]):
            return population[0]
        return None
    
    def get_best_neighbour(self, neighbours, current_word):
        next_word = neighbours.pop()
        for neighbour in neighbours: 
            if self.graph.get_pheromones(current_word, next_word) < self.graph.get_pheromones(current_word, neighbour):
                next_word = neighbour
            return next_word
        
    def run(self):
#         print(self.problem.words)
        for i in range(self.no_gens):
            self.iteration()
      
            best_ant = self.get_best_ant()
        
            if best_ant.fitness(self.problem) == 0: 
                return best_ant
            
#             PRINT EVERY GENERATION
#             for index, ant in enumerate(self.population):
#                 print("ant {}".format(index))
#                 print("solution {}".format(ant.solution))
#                 print("fitness {}".format(ant.fitness(self.problem)))
#             print('-' * 100)

            self.evaporation()
            self.population = [] 
        self.graph = deepcopy(self.problem.graph)
        return best_ant
    
    def evaporation(self):
        self.graph.decrease_pheromones_on_all_edges(self.evaporation_coefficient)

    
    def spread_pheromones_on_path(self, best_ant):
        ant = deepcopy(best_ant)
        x1 = ant.soution.pop()
        while len(ant.solution) > 0:
            x2 = ant.solution.pop()
            self.graph.add_pheromones(x1, x2, self.global_pheromone_increase)
            x1 = x2
    
    def load_parameters(self, params_file_name):
        with open(params_file_name, 'r') as file:
            
            line = file.readline().strip()
            self.no_runs = int(line.replace("number of runs:",""))
            
            line = file.readline().strip()
            self.no_gens = int(line.replace("number of generations:",""))
            
            line = file.readline().strip()
            self.local_pheromone_increase = float(line.replace("local pheromone increase:",""))
            
            line = file.readline().strip()
            self.global_pheromone_increase = float(line.replace("global pheromone increase:",""))
            
            line = file.readline().strip()
            self.evaporation_coefficient = float(line.replace("evaporation coefficient:",""))
            
            line = file.readline().strip()
            self.probability_for_best = float(line.replace("probability for best:",""))

# %%
class UI:
    def __init__(self, controller):
        self.controller = controller
        
    def main(self):
        print("computing one solution..")
        best_ant = self.controller.run()
        print("{} fitness {}".format(best_ant.solution, best_ant.fitness(self.controller.problem)))

controller = Controller("medium.txt", "params.txt")
ui = UI(controller)
ui.main()
# Out:
# computing one solution..
# ant 0
# solution ['haidema', 'haidema', 'adgitab', 'mngcnaa', 'eogaalf', 'elefant', 'dcapfal']
# fitness 7
# ant 1
# solution ['anacond', 'iobaggg', 'anacond', 'haidema', 'adgitab', 'moralaa', 'mngcnaa']
# fitness 7
# ant 2
# solution ['iobaggg', 'iabsera', 'moralaa', 'anoelon', 'dcapfal', 'anoelon', 'anacond']
# fitness 8
# ant 3
# solution ['despaci', 'adgitab', 'elefant', 'adgitab', 'mngcnaa', 'iabsera', 'eogaalf']
# fitness 8
# ant 4
# solution ['elefant', 'mngcnaa', 'anoelon', 'haidema', 'dcapfal', 'elefant', 'adgitab']
# fitness 7
# ant 5
# solution ['moralaa', 'adgitab', 'mngcnaa', 'analfab', 'despaci', 'iobaggg', 'mngcnaa']
# fitness 8
# ant 6
# solution ['analfab', 'dcapfal', 'adgitab', 'mngcnaa', 'dcapfal', 'eogaalf', 'iabsera']
# fitness 8
# ant 7
# solution ['haidema', 'adgitab', 'dcapfal', 'analfab', 'haidema', 'anoelon', 'mngcnaa']
# fitness 7
# ant 8
# solution ['anoelon', 'haidema', 'adgitab', 'mngcnaa', 'iabsera', 'anoelon', 'eogaalf']
# fitness 7
# ant 9
# solution ['iabsera', 'iobaggg', 'adgitab', 'anoelon', 'elefant', 'adgitab', 'haidema']
# fitness 7
# ant 10
# solution ['dcapfal', 'moralaa', 'analfab', 'adgitab', 'elefant', 'mngcnaa', 'moralaa']
# fitness 8
# ant 11
# solution ['eogaalf', 'anacond', 'dcapfal', 'adgitab', 'dcapfal', 'anacond', 'mngcnaa']
# fitness 9
# ant 12
# solution ['mngcnaa', 'haidema', 'adgitab', 'elefant', 'mngcnaa', 'eogaalf', 'despaci']
# fitness 7
# ant 13
# solution ['adgitab', 'haidema', 'dcapfal', 'mngcnaa', 'haidema', 'eogaalf', 'dcapfal']
# fitness 8
# ----------------------------------------------------------------------------------------------------
# ant 0
# solution ['haidema', 'adgitab', 'mngcnaa', 'eogaalf', 'anacond', 'dcapfal', 'mngcnaa']
# fitness 7
# ant 1
# solution ['anacond', 'adgitab', 'mngcnaa', 'eogaalf', 'mngcnaa', 'haidema', 'moralaa']
# fitness 7
# ant 2
# solution ['iobaggg', 'adgitab', 'despaci', 'mngcnaa', 'haidema', 'mngcnaa', 'haidema']
# fitness 8
# ant 3
# solution ['despaci', 'adgitab', 'mngcnaa', 'eogaalf', 'dcapfal', 'haidema', 'elefant']
# fitness 6
# ant 4
# solution ['elefant', 'adgitab', 'mngcnaa', 'elefant', 'eogaalf', 'iabsera', 'dcapfal']
# fitness 8
# ant 5
# solution ['moralaa', 'adgitab', 'haidema', 'analfab', 'mngcnaa', 'eogaalf', 'analfab']
# fitness 7
# ant 6
# solution ['analfab', 'iobaggg', 'adgitab', 'haidema', 'mngcnaa', 'moralaa', 'eogaalf']
# fitness 6
# ant 7
# solution ['haidema', 'eogaalf', 'moralaa', 'adgitab', 'haidema', 'mngcnaa', 'haidema']
# fitness 8
# ant 8
# solution ['anoelon', 'haidema', 'adgitab', 'mngcnaa', 'eogaalf', 'elefant', 'mngcnaa']
# fitness 7
# ant 9
# solution ['iabsera', 'elefant', 'iobaggg', 'haidema', 'anacond', 'adgitab', 'mngcnaa']
# fitness 6
# ant 10
# solution ['dcapfal', 'adgitab', 'elefant', 'iabsera', 'elefant', 'mngcnaa', 'anoelon']
# fitness 8
# ant 11
# solution ['eogaalf', 'adgitab', 'mngcnaa', 'dcapfal', 'haidema', 'iabsera', 'anoelon']
# fitness 6
# ant 12
# solution ['mngcnaa', 'despaci', 'adgitab', 'anacond', 'dcapfal', 'analfab', 'anacond']
# fitness 8
# ant 13
# solution ['adgitab', 'iabsera', 'analfab', 'mngcnaa', 'eogaalf', 'anacond', 'elefant']
# fitness 7
# ----------------------------------------------------------------------------------------------------
# ant 0
# solution ['haidema', 'adgitab', 'iobaggg', 'dcapfal', 'anacond', 'iabsera', 'haidema']
# fitness 7
# ant 1
# solution ['anacond', 'adgitab', 'iobaggg', 'mngcnaa', 'haidema', 'eogaalf', 'dcapfal']
# fitness 6
# ant 2
# solution ['iobaggg', 'despaci', 'iabsera', 'adgitab', 'iobaggg', 'mngcnaa', 'eogaalf']
# fitness 8
# ant 3
# solution ['despaci', 'eogaalf', 'adgitab', 'analfab', 'mngcnaa', 'adgitab', 'haidema']
# fitness 7
# ant 4
# solution ['elefant', 'haidema', 'adgitab', 'elefant', 'moralaa', 'anoelon', 'iobaggg']
# fitness 7
# ant 5
# solution ['moralaa', 'haidema', 'adgitab', 'eogaalf', 'analfab', 'mngcnaa', 'dcapfal']
# fitness 6
# ant 6
# solution ['analfab', 'adgitab', 'despaci', 'mngcnaa', 'anoelon', 'eogaalf', 'elefant']
# fitness 7
# ant 7
# solution ['haidema', 'haidema', 'anoelon', 'elefant', 'despaci', 'iabsera', 'adgitab']
# fitness 7
# ant 8
# solution ['anoelon', 'moralaa', 'haidema', 'eogaalf', 'adgitab', 'mngcnaa', 'adgitab']
# fitness 7
# ant 9
# solution ['iabsera', 'moralaa', 'analfab', 'adgitab', 'haidema', 'mngcnaa', 'haidema']
# fitness 7
# ant 10
# solution ['dcapfal', 'haidema', 'anacond', 'haidema', 'eogaalf', 'adgitab', 'despaci']
# fitness 7
# ant 11
# solution ['eogaalf', 'analfab', 'haidema', 'anacond', 'adgitab', 'despaci', 'eogaalf']
# fitness 7
# ant 12
# solution ['mngcnaa', 'anoelon', 'adgitab', 'dcapfal', 'moralaa', 'elefant', 'eogaalf']
# fitness 7
# ant 13
# solution ['adgitab', 'anacond', 'despaci', 'mngcnaa', 'anacond', 'anoelon', 'haidema']
# fitness 7
# ----------------------------------------------------------------------------------------------------
# ant 0
# solution ['haidema', 'adgitab', 'haidema', 'anacond', 'haidema', 'mngcnaa', 'despaci']
# fitness 8
# ant 1
# solution ['anacond', 'adgitab', 'mngcnaa', 'anacond', 'adgitab', 'eogaalf', 'elefant']
# fitness 9
# ant 2
# solution ['iobaggg', 'adgitab', 'iabsera', 'mngcnaa', 'analfab', 'haidema', 'eogaalf']
# fitness 6
# ant 3
# solution ['despaci', 'haidema', 'analfab', 'adgitab', 'anoelon', 'mngcnaa', 'haidema']
# fitness 7
# ant 4
# solution ['elefant', 'haidema', 'iobaggg', 'dcapfal', 'haidema', 'moralaa', 'anoelon']
# fitness 7
# ant 5
# solution ['moralaa', 'adgitab', 'iobaggg', 'mngcnaa', 'eogaalf', 'iabsera', 'dcapfal']
# fitness 7
# ant 6
# solution ['analfab', 'adgitab', 'eogaalf', 'analfab', 'mngcnaa', 'eogaalf', 'moralaa']
# fitness 9
# ant 7
# solution ['haidema', 'iobaggg', 'adgitab', 'elefant', 'eogaalf', 'iobaggg', 'mngcnaa']
# fitness 7
# ant 8
# solution ['anoelon', 'eogaalf', 'haidema', 'iobaggg', 'adgitab', 'moralaa', 'haidema']
# fitness 7
# ant 9
# solution ['iabsera', 'adgitab', 'mngcnaa', 'iobaggg', 'moralaa', 'analfab', 'haidema']
# fitness 6
# ant 10
# solution ['dcapfal', 'iobaggg', 'adgitab', 'iabsera', 'haidema', 'despaci', 'dcapfal']
# fitness 7
# ant 11
# solution ['eogaalf', 'anoelon', 'iabsera', 'adgitab', 'eogaalf', 'mngcnaa', 'anacond']
# fitness 8
# ant 12
# solution ['mngcnaa', 'dcapfal', 'analfab', 'dcapfal', 'mngcnaa', 'dcapfal', 'haidema']
# fitness 9
# ant 13
# solution ['adgitab', 'haidema', 'mngcnaa', 'eogaalf', 'dcapfal', 'iabsera', 'anoelon']
# fitness 6
# ----------------------------------------------------------------------------------------------------
# ant 0
# solution ['haidema', 'mngcnaa', 'adgitab', 'anacond', 'eogaalf', 'elefant', 'dcapfal']
# fitness 6
# ant 1
# solution ['anacond', 'dcapfal', 'elefant', 'haidema', 'iabsera', 'haidema', 'adgitab']
# fitness 7
# ant 2
# solution ['iobaggg', 'adgitab', 'analfab', 'mngcnaa', 'eogaalf', 'despaci', 'dcapfal']
# fitness 7
# ant 3
# solution ['despaci', 'haidema', 'analfab', 'elefant', 'iabsera', 'adgitab', 'mngcnaa']
# fitness 6
# ant 4
# solution ['elefant', 'haidema', 'adgitab', 'mngcnaa', 'analfab', 'moralaa', 'dcapfal']
# fitness 6
# ant 5
# solution ['moralaa', 'adgitab', 'mngcnaa', 'haidema', 'analfab', 'iobaggg', 'eogaalf']
# fitness 6
# ant 6
# solution ['analfab', 'haidema', 'moralaa', 'dcapfal', 'adgitab', 'mngcnaa', 'eogaalf']
# fitness 6
# ant 7
# solution ['haidema', 'iobaggg', 'anoelon', 'adgitab', 'haidema', 'iabsera', 'eogaalf']
# fitness 7
# ant 8
# solution ['anoelon', 'analfab', 'haidema', 'adgitab', 'mngcnaa', 'eogaalf', 'analfab']
# fitness 7
# ant 9
# solution ['iabsera', 'adgitab', 'despaci', 'adgitab', 'mngcnaa', 'eogaalf', 'elefant']
# fitness 8
# ant 10
# solution ['dcapfal', 'eogaalf', 'analfab', 'anacond', 'adgitab', 'haidema', 'mngcnaa']
# fitness 6
# ant 11
# solution ['eogaalf', 'iabsera', 'adgitab', 'analfab', 'iabsera', 'moralaa', 'eogaalf']
# fitness 9
# ant 12
# solution ['mngcnaa', 'adgitab', 'anoelon', 'eogaalf', 'elefant', 'adgitab', 'iabsera']
# fitness 8
# ant 13
# solution ['adgitab', 'dcapfal', 'haidema', 'mngcnaa', 'eogaalf', 'analfab', 'moralaa']
# fitness 6
# ----------------------------------------------------------------------------------------------------
# ant 0
# solution ['haidema', 'dcapfal', 'anoelon', 'haidema', 'adgitab', 'anoelon', 'haidema']
# fitness 9
# ant 1
# solution ['anacond', 'despaci', 'adgitab', 'eogaalf', 'mngcnaa', 'haidema', 'moralaa']
# fitness 6
# ant 2
# solution ['iobaggg', 'moralaa', 'adgitab', 'mngcnaa', 'analfab', 'haidema', 'mngcnaa']
# fitness 7
# ant 3
# solution ['despaci', 'adgitab', 'mngcnaa', 'eogaalf', 'iabsera', 'iobaggg', 'dcapfal']
# fitness 7
# ant 4
# solution ['elefant', 'haidema', 'adgitab', 'mngcnaa', 'dcapfal', 'eogaalf', 'anacond']
# fitness 6
# ant 5
# solution ['moralaa', 'dcapfal', 'moralaa', 'despaci', 'analfab', 'haidema', 'adgitab']
# fitness 7
# ant 6
# solution ['analfab', 'haidema', 'dcapfal', 'analfab', 'dcapfal', 'anacond', 'despaci']
# fitness 8
# ant 7
# solution ['haidema', 'anoelon', 'adgitab', 'iobaggg', 'mngcnaa', 'anacond', 'dcapfal']
# fitness 6
# ant 8
# solution ['anoelon', 'adgitab', 'mngcnaa', 'elefant', 'adgitab', 'analfab', 'haidema']
# fitness 7
# ant 9
# solution ['iabsera', 'haidema', 'elefant', 'adgitab', 'mngcnaa', 'adgitab', 'anacond']
# fitness 7
# ant 10
# solution ['dcapfal', 'despaci', 'adgitab', 'iabsera', 'iobaggg', 'haidema', 'mngcnaa']
# fitness 6
# ant 11
# solution ['eogaalf', 'haidema', 'anacond', 'haidema', 'adgitab', 'iabsera', 'eogaalf']
# fitness 8
# ant 12
# solution ['mngcnaa', 'haidema', 'despaci', 'adgitab', 'mngcnaa', 'eogaalf', 'dcapfal']
# fitness 7
# ant 13
# solution ['adgitab', 'mngcnaa', 'eogaalf', 'dcapfal', 'elefant', 'despaci', 'analfab']
# fitness 7
# ----------------------------------------------------------------------------------------------------
# ant 0
# solution ['haidema', 'mngcnaa', 'elefant', 'adgitab', 'anacond', 'eogaalf', 'elefant']
# fitness 7
# ant 1
# solution ['anacond', 'haidema', 'iobaggg', 'despaci', 'adgitab', 'eogaalf', 'haidema']
# fitness 7
# ant 2
# solution ['iobaggg', 'adgitab', 'iobaggg', 'moralaa', 'adgitab', 'mngcnaa', 'adgitab']
# fitness 10
# ant 3
# solution ['despaci', 'adgitab', 'haidema', 'elefant', 'anoelon', 'mngcnaa', 'moralaa']
# fitness 6
# ant 4
# solution ['elefant', 'iabsera', 'mngcnaa', 'analfab', 'haidema', 'elefant', 'adgitab']
# fitness 7
# ant 5
# solution ['moralaa', 'despaci', 'anacond', 'haidema', 'adgitab', 'haidema', 'mngcnaa']
# fitness 7
# ant 6
# solution ['analfab', 'haidema', 'iobaggg', 'haidema', 'iabsera', 'elefant', 'adgitab']
# fitness 7
# ant 7
# solution ['haidema', 'adgitab', 'moralaa', 'mngcnaa', 'adgitab', 'anacond', 'eogaalf']
# fitness 7
# ant 8
# solution ['anoelon', 'adgitab', 'mngcnaa', 'iabsera', 'anoelon', 'mngcnaa', 'anacond']
# fitness 9
# ant 9
# solution ['iabsera', 'haidema', 'iabsera', 'adgitab', 'mngcnaa', 'elefant', 'mngcnaa']
# fitness 8
# ant 10
# solution ['dcapfal', 'haidema', 'adgitab', 'despaci', 'haidema', 'iabsera', 'mngcnaa']
# fitness 7
# ant 11
# solution ['eogaalf', 'haidema', 'adgitab', 'iabsera', 'mngcnaa', 'dcapfal', 'analfab']
# fitness 6
# ant 12
# solution ['mngcnaa', 'adgitab', 'moralaa', 'haidema', 'elefant', 'eogaalf', 'anoelon']
# fitness 6
# ant 13
# solution ['adgitab', 'despaci', 'mngcnaa', 'elefant', 'eogaalf', 'dcapfal', 'anacond']
# fitness 7
# ----------------------------------------------------------------------------------------------------
# ant 0
# solution ['haidema', 'mngcnaa', 'adgitab', 'mngcnaa', 'despaci', 'eogaalf', 'dcapfal']
# fitness 7
# ant 1
# solution ['anacond', 'haidema', 'dcapfal', 'moralaa', 'adgitab', 'anoelon', 'mngcnaa']
# fitness 6
# ant 2
# solution ['iobaggg', 'anoelon', 'dcapfal', 'haidema', 'adgitab', 'haidema', 'mngcnaa']
# fitness 7
# ant 3
# solution ['despaci', 'elefant', 'moralaa', 'haidema', 'dcapfal', 'haidema', 'elefant']
# fitness 8
# ant 4
# solution ['elefant', 'dcapfal', 'haidema', 'anacond', 'adgitab', 'eogaalf', 'iabsera']
# fitness 6
# ant 5
# solution ['moralaa', 'haidema', 'adgitab', 'iobaggg', 'iabsera', 'mngcnaa', 'eogaalf']
# fitness 6
# ant 6
# solution ['analfab', 'elefant', 'haidema', 'anacond', 'elefant', 'haidema', 'elefant']
# fitness 9
# ant 7
# solution ['haidema', 'eogaalf', 'adgitab', 'dcapfal', 'iobaggg', 'analfab', 'mngcnaa']
# fitness 6
# ant 8
# solution ['anoelon', 'anacond', 'haidema', 'adgitab', 'eogaalf', 'mngcnaa', 'anacond']
# fitness 7
# ant 9
# solution ['iabsera', 'adgitab', 'anoelon', 'anacond', 'mngcnaa', 'eogaalf', 'haidema']
# fitness 6
# ant 10
# solution ['dcapfal', 'anacond', 'adgitab', 'analfab', 'iobaggg', 'mngcnaa', 'eogaalf']
# fitness 7
# ant 11
# solution ['eogaalf', 'haidema', 'adgitab', 'dcapfal', 'elefant', 'mngcnaa', 'iabsera']
# fitness 6
# ant 12
# solution ['mngcnaa', 'adgitab', 'haidema', 'haidema', 'elefant', 'eogaalf', 'dcapfal']
# fitness 7
# ant 13
# solution ['adgitab', 'iobaggg', 'adgitab', 'mngcnaa', 'eogaalf', 'dcapfal', 'haidema']
# fitness 7
# ----------------------------------------------------------------------------------------------------
# ant 0
# solution ['haidema', 'dcapfal', 'adgitab', 'iobaggg', 'iabsera', 'mngcnaa', 'eogaalf']
# fitness 6
# ant 1
# solution ['anacond', 'adgitab', 'moralaa', 'haidema', 'mngcnaa', 'moralaa', 'dcapfal']
# fitness 7
# ant 2
# solution ['iobaggg', 'analfab', 'moralaa', 'despaci', 'anacond', 'adgitab', 'dcapfal']
# fitness 7
# ant 3
# solution ['despaci', 'eogaalf', 'despaci', 'iabsera', 'iobaggg', 'moralaa', 'anacond']
# fitness 8
# ant 4
# solution ['elefant', 'analfab', 'despaci', 'iabsera', 'haidema', 'mngcnaa', 'adgitab']
# fitness 6
# ant 5
# solution ['moralaa', 'iabsera', 'adgitab', 'mngcnaa', 'anoelon', 'analfab', 'haidema']
# fitness 6
# ant 6
# solution ['analfab', 'haidema', 'dcapfal', 'iabsera', 'adgitab', 'mngcnaa', 'moralaa']
# fitness 6
# ant 7
# solution ['haidema', 'adgitab', 'despaci', 'anoelon', 'iobaggg', 'mngcnaa', 'adgitab']
# fitness 7
# ant 8
# solution ['anoelon', 'adgitab', 'mngcnaa', 'adgitab', 'haidema', 'eogaalf', 'elefant']
# fitness 7
# ant 9
# solution ['iabsera', 'moralaa', 'analfab', 'haidema', 'anoelon', 'haidema', 'eogaalf']
# fitness 7
# ant 10
# solution ['dcapfal', 'haidema', 'haidema', 'despaci', 'haidema', 'adgitab', 'mngcnaa']
# fitness 8
# ant 11
# solution ['eogaalf', 'analfab', 'anacond', 'analfab', 'iobaggg', 'adgitab', 'mngcnaa']
# fitness 8
# ant 12
# solution ['mngcnaa', 'adgitab', 'haidema', 'eogaalf', 'dcapfal', 'anacond', 'moralaa']
# fitness 6
# ant 13
# solution ['adgitab', 'mngcnaa', 'elefant', 'haidema', 'iobaggg', 'eogaalf', 'iobaggg']
# fitness 7
# ----------------------------------------------------------------------------------------------------
# ant 0
# solution ['haidema', 'adgitab', 'mngcnaa', 'eogaalf', 'anacond', 'anoelon', 'anacond']
# fitness 7
# ant 1
# solution ['anacond', 'adgitab', 'mngcnaa', 'analfab', 'haidema', 'eogaalf', 'dcapfal']
# fitness 6
# ant 2
# solution ['iobaggg', 'adgitab', 'iabsera', 'mngcnaa', 'eogaalf', 'dcapfal', 'iabsera']
# fitness 8
# ant 3
# solution ['despaci', 'adgitab', 'anacond', 'haidema', 'mngcnaa', 'iobaggg', 'eogaalf']
# fitness 6
# ant 4
# solution ['elefant', 'haidema', 'mngcnaa', 'adgitab', 'haidema', 'eogaalf', 'dcapfal']
# fitness 7
# ant 5
# solution ['moralaa', 'iobaggg', 'dcapfal', 'haidema', 'adgitab', 'moralaa', 'iabsera']
# fitness 7
# ant 6
# solution ['analfab', 'haidema', 'haidema', 'adgitab', 'despaci', 'anacond', 'mngcnaa']
# fitness 7
# ant 7
# solution ['haidema', 'anoelon', 'adgitab', 'analfab', 'moralaa', 'mngcnaa', 'haidema']
# fitness 7
# ant 8
# solution ['anoelon', 'analfab', 'anacond', 'adgitab', 'mngcnaa', 'adgitab', 'analfab']
# fitness 9
# ant 9
# solution ['iabsera', 'despaci', 'anacond', 'adgitab', 'mngcnaa', 'haidema', 'eogaalf']
# fitness 6
# ant 10
# solution ['dcapfal', 'haidema', 'iobaggg', 'elefant', 'anacond', 'adgitab', 'anacond']
# fitness 7
# ant 11
# solution ['eogaalf', 'haidema', 'anacond', 'adgitab', 'haidema', 'dcapfal', 'mngcnaa']
# fitness 7
# ant 12
# solution ['mngcnaa', 'adgitab', 'haidema', 'anacond', 'eogaalf', 'dcapfal', 'eogaalf']
# fitness 7
# ant 13
# solution ['adgitab', 'eogaalf', 'mngcnaa', 'haidema', 'dcapfal', 'iabsera', 'eogaalf']
# fitness 7
# ----------------------------------------------------------------------------------------------------
# ant 0
# solution ['haidema', 'adgitab', 'eogaalf', 'moralaa', 'mngcnaa', 'anoelon', 'moralaa']
# fitness 7
# ant 1
# solution ['anacond', 'dcapfal', 'mngcnaa', 'adgitab', 'haidema', 'anacond', 'eogaalf']
# fitness 7
# ant 2
# solution ['iobaggg', 'mngcnaa', 'anacond', 'iobaggg', 'adgitab', 'dcapfal', 'eogaalf']
# fitness 8
# ant 3
# solution ['despaci', 'adgitab', 'anoelon', 'eogaalf', 'dcapfal', 'haidema', 'mngcnaa']
# fitness 6
# ant 4
# solution ['elefant', 'despaci', 'adgitab', 'elefant', 'haidema', 'mngcnaa', 'eogaalf']
# fitness 7
# ant 5
# solution ['moralaa', 'haidema', 'elefant', 'moralaa', 'anacond', 'dcapfal', 'adgitab']
# fitness 7
# ant 6
# solution ['analfab', 'anoelon', 'dcapfal', 'iabsera', 'adgitab', 'iabsera', 'mngcnaa']
# fitness 8
# ant 7
# solution ['haidema', 'adgitab', 'haidema', 'mngcnaa', 'despaci', 'iobaggg', 'anacond']
# fitness 7
# ant 8
# solution ['anoelon', 'adgitab', 'iobaggg', 'elefant', 'haidema', 'moralaa', 'mngcnaa']
# fitness 6
# ant 9
# solution ['iabsera', 'adgitab', 'anacond', 'haidema', 'haidema', 'mngcnaa', 'eogaalf']
# fitness 7
# ant 10
# solution ['dcapfal', 'anacond', 'moralaa', 'adgitab', 'elefant', 'haidema', 'analfab']
# fitness 6
# ant 11
# solution ['eogaalf', 'haidema', 'adgitab', 'moralaa', 'despaci', 'iobaggg', 'analfab']
# fitness 6
# ant 12
# solution ['mngcnaa', 'elefant', 'eogaalf', 'haidema', 'adgitab', 'anacond', 'adgitab']
# fitness 7
# ant 13
# solution ['adgitab', 'mngcnaa', 'anacond', 'adgitab', 'eogaalf', 'mngcnaa', 'haidema']
# fitness 8
# ----------------------------------------------------------------------------------------------------
# ant 0
# solution ['haidema', 'dcapfal', 'adgitab', 'iobaggg', 'haidema', 'mngcnaa', 'eogaalf']
# fitness 7
# ant 1
# solution ['anacond', 'adgitab', 'moralaa', 'mngcnaa', 'eogaalf', 'dcapfal', 'elefant']
# fitness 7
# ant 2
# solution ['iobaggg', 'adgitab', 'eogaalf', 'mngcnaa', 'haidema', 'dcapfal', 'moralaa']
# fitness 6
# ant 3
# solution ['despaci', 'adgitab', 'mngcnaa', 'eogaalf', 'analfab', 'anacond', 'haidema']
# fitness 6
# ant 4
# solution ['elefant', 'dcapfal', 'despaci', 'adgitab', 'despaci', 'mngcnaa', 'despaci']
# fitness 9
# ant 5
# solution ['moralaa', 'adgitab', 'iobaggg', 'mngcnaa', 'eogaalf', 'iabsera', 'mngcnaa']
# fitness 8
# ant 6
# solution ['analfab', 'eogaalf', 'haidema', 'adgitab', 'dcapfal', 'anacond', 'mngcnaa']
# fitness 6
# ant 7
# solution ['haidema', 'iobaggg', 'mngcnaa', 'elefant', 'iabsera', 'adgitab', 'dcapfal']
# fitness 6
# ant 8
# solution ['anoelon', 'eogaalf', 'haidema', 'haidema', 'iabsera', 'adgitab', 'mngcnaa']
# fitness 7
# ant 9
# solution ['iabsera', 'adgitab', 'anoelon', 'mngcnaa', 'haidema', 'iabsera', 'eogaalf']
# fitness 7
# ant 10
# solution ['dcapfal', 'anacond', 'adgitab', 'mngcnaa', 'eogaalf', 'haidema', 'iabsera']
# fitness 6
# ant 11
# solution ['eogaalf', 'anoelon', 'adgitab', 'mngcnaa', 'haidema', 'dcapfal', 'analfab']
# fitness 6
# ant 12
# solution ['mngcnaa', 'anoelon', 'adgitab', 'haidema', 'iabsera', 'eogaalf', 'adgitab']
# fitness 7
# ant 13
# solution ['adgitab', 'mngcnaa', 'despaci', 'adgitab', 'haidema', 'eogaalf', 'haidema']
# fitness 8
# ----------------------------------------------------------------------------------------------------
# ant 0
# solution ['haidema', 'analfab', 'elefant', 'adgitab', 'anoelon', 'adgitab', 'haidema']
# fitness 8
# ant 1
# solution ['anacond', 'dcapfal', 'haidema', 'analfab', 'anoelon', 'adgitab', 'haidema']
# fitness 7
# ant 2
# solution ['iobaggg', 'despaci', 'elefant', 'mngcnaa', 'anacond', 'iobaggg', 'eogaalf']
# fitness 8
# ant 3
# solution ['despaci', 'adgitab', 'haidema', 'anoelon', 'adgitab', 'iobaggg', 'mngcnaa']
# fitness 7
# ant 4
# solution ['elefant', 'anoelon', 'iobaggg', 'haidema', 'adgitab', 'anacond', 'moralaa']
# fitness 6
# ant 5
# solution ['moralaa', 'adgitab', 'mngcnaa', 'eogaalf', 'elefant', 'iobaggg', 'dcapfal']
# fitness 7
# ant 6
# solution ['analfab', 'haidema', 'adgitab', 'mngcnaa', 'anacond', 'eogaalf', 'iobaggg']
# fitness 6
# ant 7
# solution ['haidema', 'moralaa', 'haidema', 'adgitab', 'mngcnaa', 'moralaa', 'mngcnaa']
# fitness 9
# ant 8
# solution ['anoelon', 'adgitab', 'moralaa', 'mngcnaa', 'dcapfal', 'haidema', 'eogaalf']
# fitness 6
# ant 9
# solution ['iabsera', 'adgitab', 'iabsera', 'haidema', 'eogaalf', 'mngcnaa', 'despaci']
# fitness 7
# ant 10
# solution ['dcapfal', 'iabsera', 'adgitab', 'anacond', 'haidema', 'anoelon', 'mngcnaa']
# fitness 6
# ant 11
# solution ['eogaalf', 'haidema', 'adgitab', 'eogaalf', 'adgitab', 'despaci', 'anacond']
# fitness 8
# ant 12
# solution ['mngcnaa', 'haidema', 'eogaalf', 'haidema', 'adgitab', 'iobaggg', 'dcapfal']
# fitness 7
# ant 13
# solution ['adgitab', 'despaci', 'anacond', 'haidema', 'moralaa', 'haidema', 'mngcnaa']
# fitness 7
# ----------------------------------------------------------------------------------------------------
# ant 0
# solution ['haidema', 'adgitab', 'mngcnaa', 'dcapfal', 'haidema', 'mngcnaa', 'eogaalf']
# fitness 8
# ant 1
# solution ['anacond', 'iabsera', 'adgitab', 'mngcnaa', 'eogaalf', 'analfab', 'anacond']
# fitness 8
# ant 2
# solution ['iobaggg', 'adgitab', 'mngcnaa', 'iabsera', 'moralaa', 'haidema', 'analfab']
# fitness 6
# ant 3
# solution ['despaci', 'adgitab', 'mngcnaa', 'despaci', 'dcapfal', 'elefant', 'eogaalf']
# fitness 8
# ant 4
# solution ['elefant', 'haidema', 'moralaa', 'dcapfal', 'eogaalf', 'analfab', 'iabsera']
# fitness 6
# ant 5
# solution ['moralaa', 'adgitab', 'mngcnaa', 'moralaa', 'haidema', 'eogaalf', 'mngcnaa']
# fitness 8
# ant 6
# solution ['analfab', 'anoelon', 'adgitab', 'mngcnaa', 'haidema', 'haidema', 'iobaggg']
# fitness 7
# ant 7
# solution ['haidema', 'elefant', 'anacond', 'adgitab', 'dcapfal', 'moralaa', 'anacond']
# fitness 7
# ant 8
# solution ['anoelon', 'adgitab', 'analfab', 'mngcnaa', 'eogaalf', 'dcapfal', 'iobaggg']
# fitness 7
# ant 9
# solution ['iabsera', 'elefant', 'adgitab', 'iobaggg', 'moralaa', 'eogaalf', 'mngcnaa']
# fitness 7
# ant 10
# solution ['dcapfal', 'anacond', 'adgitab', 'mngcnaa', 'anacond', 'eogaalf', 'haidema']
# fitness 7
# ant 11
# solution ['eogaalf', 'elefant', 'adgitab', 'anoelon', 'elefant', 'haidema', 'eogaalf']
# fitness 8
# ant 12
# solution ['mngcnaa', 'dcapfal', 'haidema', 'mngcnaa', 'dcapfal', 'adgitab', 'anacond']
# fitness 8
# ant 13
# solution ['adgitab', 'dcapfal', 'adgitab', 'iabsera', 'moralaa', 'eogaalf', 'elefant']
# fitness 8
# ----------------------------------------------------------------------------------------------------
# ant 0
# solution ['haidema', 'adgitab', 'mngcnaa', 'moralaa', 'anacond', 'anoelon', 'iobaggg']
# fitness 6
# ant 1
# solution ['anacond', 'adgitab', 'mngcnaa', 'eogaalf', 'anoelon', 'anacond', 'adgitab']
# fitness 9
# ant 2
# solution ['iobaggg', 'adgitab', 'mngcnaa', 'anacond', 'despaci', 'eogaalf', 'dcapfal']
# fitness 7
# ant 3
# solution ['despaci', 'analfab', 'despaci', 'adgitab', 'haidema', 'mngcnaa', 'moralaa']
# fitness 7
# ant 4
# solution ['elefant', 'adgitab', 'elefant', 'haidema', 'anacond', 'eogaalf', 'elefant']
# fitness 8
# ant 5
# solution ['moralaa', 'anoelon', 'haidema', 'mngcnaa', 'haidema', 'iabsera', 'adgitab']
# fitness 7
# ant 6
# solution ['analfab', 'anoelon', 'adgitab', 'elefant', 'haidema', 'mngcnaa', 'eogaalf']
# fitness 6
# ant 7
# solution ['haidema', 'mngcnaa', 'anoelon', 'moralaa', 'dcapfal', 'iobaggg', 'adgitab']
# fitness 6
# ant 8
# solution ['anoelon', 'anacond', 'anoelon', 'iobaggg', 'haidema', 'iobaggg', 'anoelon']
# fitness 9
# ant 9
# solution ['iabsera', 'adgitab', 'dcapfal', 'elefant', 'anoelon', 'elefant', 'haidema']
# fitness 7
# ant 10
# solution ['dcapfal', 'haidema', 'anoelon', 'elefant', 'analfab', 'iabsera', 'haidema']
# fitness 7
# ant 11
# solution ['eogaalf', 'haidema', 'adgitab', 'anoelon', 'haidema', 'dcapfal', 'mngcnaa']
# fitness 7
# ant 12
# solution ['mngcnaa', 'adgitab', 'despaci', 'dcapfal', 'haidema', 'mngcnaa', 'adgitab']
# fitness 8
# ant 13
# solution ['adgitab', 'haidema', 'analfab', 'mngcnaa', 'iobaggg', 'despaci', 'anacond']
# fitness 6
# ----------------------------------------------------------------------------------------------------
# ant 0
# solution ['haidema', 'adgitab', 'eogaalf', 'haidema', 'mngcnaa', 'elefant', 'dcapfal']
# fitness 7
# ant 1
# solution ['anacond', 'mngcnaa', 'adgitab', 'despaci', 'haidema', 'despaci', 'elefant']
# fitness 7
# ant 2
# solution ['iobaggg', 'adgitab', 'moralaa', 'adgitab', 'mngcnaa', 'eogaalf', 'elefant']
# fitness 8
# ant 3
# solution ['despaci', 'adgitab', 'mngcnaa', 'haidema', 'iobaggg', 'eogaalf', 'iobaggg']
# fitness 7
# ant 4
# solution ['elefant', 'dcapfal', 'haidema', 'mngcnaa', 'elefant', 'adgitab', 'anacond']
# fitness 7
# ant 5
# solution ['moralaa', 'anoelon', 'adgitab', 'analfab', 'anoelon', 'despaci', 'mngcnaa']
# fitness 8
# ant 6
# solution ['analfab', 'elefant', 'haidema', 'anoelon', 'adgitab', 'dcapfal', 'adgitab']
# fitness 7
# ant 7
# solution ['haidema', 'elefant', 'analfab', 'iabsera', 'anacond', 'adgitab', 'anoelon']
# fitness 6
# ant 8
# solution ['anoelon', 'adgitab', 'analfab', 'dcapfal', 'elefant', 'moralaa', 'elefant']
# fitness 8
# ant 9
# solution ['iabsera', 'adgitab', 'iobaggg', 'anacond', 'mngcnaa', 'eogaalf', 'despaci']
# fitness 7
# ant 10
# solution ['dcapfal', 'adgitab', 'mngcnaa', 'eogaalf', 'haidema', 'anacond', 'iabsera']
# fitness 6
# ant 11
# solution ['eogaalf', 'analfab', 'elefant', 'analfab', 'elefant', 'haidema', 'adgitab']
# fitness 8
# ant 12
# solution ['mngcnaa', 'adgitab', 'haidema', 'anacond', 'iabsera', 'adgitab', 'iobaggg']
# fitness 7
# ant 13
# solution ['adgitab', 'anacond', 'haidema', 'eogaalf', 'adgitab', 'moralaa', 'anacond']
# fitness 8
# ----------------------------------------------------------------------------------------------------
# ant 0
# solution ['haidema', 'anacond', 'adgitab', 'mngcnaa', 'adgitab', 'haidema', 'eogaalf']
# fitness 8
# ant 1
# solution ['anacond', 'haidema', 'adgitab', 'mngcnaa', 'anacond', 'eogaalf', 'dcapfal']
# fitness 7
# ant 2
# solution ['iobaggg', 'elefant', 'adgitab', 'iabsera', 'mngcnaa', 'eogaalf', 'haidema']
# fitness 6
# ant 3
# solution ['despaci', 'adgitab', 'mngcnaa', 'haidema', 'eogaalf', 'mngcnaa', 'haidema']
# fitness 8
# ant 4
# solution ['elefant', 'despaci', 'adgitab', 'haidema', 'mngcnaa', 'iobaggg', 'adgitab']
# fitness 7
# ant 5
# solution ['moralaa', 'despaci', 'dcapfal', 'haidema', 'dcapfal', 'adgitab', 'mngcnaa']
# fitness 7
# ant 6
# solution ['analfab', 'haidema', 'adgitab', 'mngcnaa', 'eogaalf', 'analfab', 'despaci']
# fitness 7
# ant 7
# solution ['haidema', 'adgitab', 'mngcnaa', 'anoelon', 'iabsera', 'anacond', 'eogaalf']
# fitness 6
# ant 8
# solution ['anoelon', 'adgitab', 'anoelon', 'elefant', 'despaci', 'mngcnaa', 'analfab']
# fitness 8
# ant 9
# solution ['iabsera', 'dcapfal', 'anoelon', 'iabsera', 'anoelon', 'adgitab', 'analfab']
# fitness 9
# ant 10
# solution ['dcapfal', 'adgitab', 'dcapfal', 'despaci', 'elefant', 'eogaalf', 'elefant']
# fitness 9
# ant 11
# solution ['eogaalf', 'elefant', 'haidema', 'iobaggg', 'haidema', 'adgitab', 'mngcnaa']
# fitness 7
# ant 12
# solution ['mngcnaa', 'anoelon', 'adgitab', 'haidema', 'anacond', 'elefant', 'mngcnaa']
# fitness 7
# ant 13
# solution ['adgitab', 'mngcnaa', 'anoelon', 'iobaggg', 'haidema', 'despaci', 'anacond']
# fitness 6
# ----------------------------------------------------------------------------------------------------
# ant 0
# solution ['haidema', 'despaci', 'adgitab', 'moralaa', 'haidema', 'mngcnaa', 'eogaalf']
# fitness 7
# ant 1
# solution ['anacond', 'adgitab', 'despaci', 'eogaalf', 'mngcnaa', 'despaci', 'moralaa']
# fitness 8
# ant 2
# solution ['iobaggg', 'anoelon', 'adgitab', 'eogaalf', 'mngcnaa', 'adgitab', 'dcapfal']
# fitness 8
# ant 3
# solution ['despaci', 'dcapfal', 'haidema', 'mngcnaa', 'iabsera', 'adgitab', 'anacond']
# fitness 6
# ant 4
# solution ['elefant', 'mngcnaa', 'iabsera', 'adgitab', 'despaci', 'eogaalf', 'anacond']
# fitness 7
# ant 5
# solution ['moralaa', 'iobaggg', 'moralaa', 'mngcnaa', 'dcapfal', 'anoelon', 'adgitab']
# fitness 8
# ant 6
# solution ['analfab', 'haidema', 'adgitab', 'mngcnaa', 'anacond', 'eogaalf', 'dcapfal']
# fitness 6
# ant 7
# solution ['haidema', 'elefant', 'eogaalf', 'analfab', 'dcapfal', 'anoelon', 'iobaggg']
# fitness 6
# ant 8
# solution ['anoelon', 'adgitab', 'anacond', 'iobaggg', 'despaci', 'mngcnaa', 'despaci']
# fitness 8
# ant 9
# solution ['iabsera', 'adgitab', 'mngcnaa', 'analfab', 'anacond', 'eogaalf', 'dcapfal']
# fitness 7
# ant 10
# solution ['dcapfal', 'haidema', 'anoelon', 'elefant', 'iobaggg', 'anacond', 'eogaalf']
# fitness 6
# ant 11
# solution ['eogaalf', 'moralaa', 'elefant', 'despaci', 'adgitab', 'mngcnaa', 'eogaalf']
# fitness 8
# ant 12
# solution ['mngcnaa', 'eogaalf', 'despaci', 'analfab', 'haidema', 'iabsera', 'haidema']
# fitness 7
# ant 13
# solution ['adgitab', 'elefant', 'mngcnaa', 'eogaalf', 'adgitab', 'mngcnaa', 'anacond']
# fitness 9
# ----------------------------------------------------------------------------------------------------
# ant 0
# solution ['haidema', 'adgitab', 'iabsera', 'haidema', 'mngcnaa', 'adgitab', 'anacond']
# fitness 8
# ant 1
# solution ['anacond', 'eogaalf', 'haidema', 'adgitab', 'anacond', 'mngcnaa', 'iobaggg']
# fitness 7
# ant 2
# solution ['iobaggg', 'haidema', 'adgitab', 'mngcnaa', 'adgitab', 'analfab', 'eogaalf']
# fitness 7
# ant 3
# solution ['despaci', 'eogaalf', 'analfab', 'dcapfal', 'haidema', 'adgitab', 'haidema']
# fitness 7
# ant 4
# solution ['elefant', 'moralaa', 'elefant', 'eogaalf', 'haidema', 'anacond', 'adgitab']
# fitness 7
# ant 5
# solution ['moralaa', 'haidema', 'dcapfal', 'adgitab', 'mngcnaa', 'anoelon', 'analfab']
# fitness 6
# ant 6
# solution ['analfab', 'iobaggg', 'iabsera', 'dcapfal', 'haidema', 'adgitab', 'mngcnaa']
# fitness 6
# ant 7
# solution ['haidema', 'iobaggg', 'anacond', 'eogaalf', 'iabsera', 'adgitab', 'dcapfal']
# fitness 6
# ant 8
# solution ['anoelon', 'moralaa', 'eogaalf', 'haidema', 'anacond', 'mngcnaa', 'anoelon']
# fitness 7
# ant 9
# solution ['iabsera', 'adgitab', 'dcapfal', 'iabsera', 'anoelon', 'anacond', 'haidema']
# fitness 7
# ant 10
# solution ['dcapfal', 'mngcnaa', 'elefant', 'haidema', 'iobaggg', 'adgitab', 'iobaggg']
# fitness 7
# ant 11
# solution ['eogaalf', 'haidema', 'adgitab', 'mngcnaa', 'dcapfal', 'eogaalf', 'dcapfal']
# fitness 8
# ant 12
# solution ['mngcnaa', 'anoelon', 'haidema', 'anacond', 'iabsera', 'iobaggg', 'eogaalf']
# fitness 6
# ant 13
# solution ['adgitab', 'moralaa', 'mngcnaa', 'iabsera', 'mngcnaa', 'eogaalf', 'dcapfal']
# fitness 8
# ----------------------------------------------------------------------------------------------------
# ant 0
# solution ['haidema', 'dcapfal', 'despaci', 'adgitab', 'despaci', 'haidema', 'adgitab']
# fitness 9
# ant 1
# solution ['anacond', 'adgitab', 'mngcnaa', 'eogaalf', 'haidema', 'eogaalf', 'adgitab']
# fitness 8
# ant 2
# solution ['iobaggg', 'adgitab', 'moralaa', 'haidema', 'adgitab', 'mngcnaa', 'eogaalf']
# fitness 7
# ant 3
# solution ['despaci', 'moralaa', 'haidema', 'adgitab', 'mngcnaa', 'eogaalf', 'despaci']
# fitness 7
# ant 4
# solution ['elefant', 'iobaggg', 'adgitab', 'anacond', 'haidema', 'dcapfal', 'anoelon']
# fitness 6
# ant 5
# solution ['moralaa', 'eogaalf', 'elefant', 'anoelon', 'adgitab', 'haidema', 'dcapfal']
# fitness 6
# ant 6
# solution ['analfab', 'haidema', 'elefant', 'despaci', 'adgitab', 'analfab', 'mngcnaa']
# fitness 7
# ant 7
# solution ['haidema', 'adgitab', 'haidema', 'mngcnaa', 'eogaalf', 'iabsera', 'anacond']
# fitness 7
# ant 8
# solution ['anoelon', 'adgitab', 'analfab', 'elefant', 'haidema', 'mngcnaa', 'eogaalf']
# fitness 6
# ant 9
# solution ['iabsera', 'elefant', 'mngcnaa', 'dcapfal', 'haidema', 'adgitab', 'analfab']
# fitness 6
# ant 10
# solution ['dcapfal', 'mngcnaa', 'iobaggg', 'adgitab', 'haidema', 'iabsera', 'haidema']
# fitness 7
# ant 11
# solution ['eogaalf', 'haidema', 'adgitab', 'mngcnaa', 'despaci', 'dcapfal', 'anacond']
# fitness 6
# ant 12
# solution ['mngcnaa', 'haidema', 'dcapfal', 'haidema', 'adgitab', 'anacond', 'analfab']
# fitness 7
# ant 13
# solution ['adgitab', 'mngcnaa', 'eogaalf', 'dcapfal', 'moralaa', 'iobaggg', 'iabsera']
# fitness 7
# ----------------------------------------------------------------------------------------------------
# ant 0
# solution ['haidema', 'adgitab', 'despaci', 'anacond', 'analfab', 'despaci', 'mngcnaa']
# fitness 7
# ant 1
# solution ['anacond', 'adgitab', 'eogaalf', 'haidema', 'adgitab', 'mngcnaa', 'haidema']
# fitness 8
# ant 2
# solution ['iobaggg', 'adgitab', 'anoelon', 'haidema', 'iabsera', 'adgitab', 'mngcnaa']
# fitness 7
# ant 3
# solution ['despaci', 'adgitab', 'mngcnaa', 'elefant', 'haidema', 'haidema', 'eogaalf']
# fitness 7
# ant 4
# solution ['elefant', 'despaci', 'adgitab', 'mngcnaa', 'iabsera', 'eogaalf', 'dcapfal']
# fitness 7
# ant 5
# solution ['moralaa', 'haidema', 'adgitab', 'despaci', 'anacond', 'adgitab', 'anoelon']
# fitness 7
# ant 6
# solution ['analfab', 'adgitab', 'moralaa', 'analfab', 'haidema', 'iobaggg', 'anacond']
# fitness 7
# ant 7
# solution ['haidema', 'anoelon', 'mngcnaa', 'eogaalf', 'adgitab', 'despaci', 'mngcnaa']
# fitness 7
# ant 8
# solution ['anoelon', 'adgitab', 'iobaggg', 'dcapfal', 'haidema', 'mngcnaa', 'elefant']
# fitness 6
# ant 9
# solution ['iabsera', 'adgitab', 'mngcnaa', 'dcapfal', 'haidema', 'moralaa', 'mngcnaa']
# fitness 7
# ant 10
# solution ['dcapfal', 'haidema', 'adgitab', 'mngcnaa', 'eogaalf', 'anacond', 'iabsera']
# fitness 6
# ant 11
# solution ['eogaalf', 'haidema', 'despaci', 'elefant', 'adgitab', 'anoelon', 'elefant']
# fitness 7
# ant 12
# solution ['mngcnaa', 'adgitab', 'haidema', 'eogaalf', 'iabsera', 'anacond', 'adgitab']
# fitness 7
# ant 13
# solution ['adgitab', 'iobaggg', 'eogaalf', 'despaci', 'anoelon', 'iobaggg', 'mngcnaa']
# fitness 8
# ----------------------------------------------------------------------------------------------------
# ant 0
# solution ['haidema', 'adgitab', 'mngcnaa', 'iabsera', 'anacond', 'dcapfal', 'moralaa']
# fitness 6
# ant 1
# solution ['anacond', 'iabsera', 'mngcnaa', 'haidema', 'anacond', 'adgitab', 'iabsera']
# fitness 8
# ant 2
# solution ['iobaggg', 'despaci', 'mngcnaa', 'adgitab', 'haidema', 'moralaa', 'anacond']
# fitness 6
# ant 3
# solution ['despaci', 'adgitab', 'mngcnaa', 'haidema', 'iobaggg', 'dcapfal', 'anacond']
# fitness 6
# ant 4
# solution ['elefant', 'analfab', 'haidema', 'adgitab', 'mngcnaa', 'haidema', 'adgitab']
# fitness 8
# ant 5
# solution ['moralaa', 'iabsera', 'eogaalf', 'analfab', 'dcapfal', 'adgitab', 'analfab']
# fitness 8
# ant 6
# solution ['analfab', 'haidema', 'analfab', 'mngcnaa', 'adgitab', 'anoelon', 'adgitab']
# fitness 8
# ant 7
# solution ['haidema', 'analfab', 'anoelon', 'moralaa', 'anacond', 'adgitab', 'dcapfal']
# fitness 6
# ant 8
# solution ['anoelon', 'elefant', 'iobaggg', 'adgitab', 'mngcnaa', 'haidema', 'despaci']
# fitness 6
# ant 9
# solution ['iabsera', 'adgitab', 'haidema', 'mngcnaa', 'eogaalf', 'haidema', 'dcapfal']
# fitness 7
# ant 10
# solution ['dcapfal', 'haidema', 'adgitab', 'iabsera', 'moralaa', 'anacond', 'haidema']
# fitness 7
# ant 11
# solution ['eogaalf', 'anoelon', 'iabsera', 'elefant', 'haidema', 'adgitab', 'analfab']
# fitness 6
# ant 12
# solution ['mngcnaa', 'adgitab', 'mngcnaa', 'haidema', 'adgitab', 'anacond', 'despaci']
# fitness 8
# ant 13
# solution ['adgitab', 'anacond', 'haidema', 'mngcnaa', 'moralaa', 'eogaalf', 'dcapfal']
# fitness 6
# ----------------------------------------------------------------------------------------------------
# ant 0
# solution ['haidema', 'mngcnaa', 'adgitab', 'anacond', 'eogaalf', 'haidema', 'despaci']
# fitness 7
# ant 1
# solution ['anacond', 'adgitab', 'mngcnaa', 'haidema', 'eogaalf', 'iobaggg', 'analfab']
# fitness 6
# ant 2
# solution ['iobaggg', 'dcapfal', 'haidema', 'adgitab', 'mngcnaa', 'analfab', 'iabsera']
# fitness 6
# ant 3
# solution ['despaci', 'adgitab', 'mngcnaa', 'haidema', 'moralaa', 'anacond', 'despaci']
# fitness 7
# ant 4
# solution ['elefant', 'haidema', 'iabsera', 'anoelon', 'dcapfal', 'adgitab', 'mngcnaa']
# fitness 6
# ant 5
# solution ['moralaa', 'iobaggg', 'adgitab', 'dcapfal', 'adgitab', 'moralaa', 'eogaalf']
# fitness 9
# ant 6
# solution ['analfab', 'adgitab', 'mngcnaa', 'dcapfal', 'haidema', 'iobaggg', 'elefant']
# fitness 6
# ant 7
# solution ['haidema', 'iobaggg', 'haidema', 'adgitab', 'mngcnaa', 'eogaalf', 'dcapfal']
# fitness 7
# ant 8
# solution ['anoelon', 'analfab', 'haidema', 'analfab', 'adgitab', 'mngcnaa', 'haidema']
# fitness 8
# ant 9
# solution ['iabsera', 'adgitab', 'mngcnaa', 'dcapfal', 'haidema', 'eogaalf', 'moralaa']
# fitness 6
# ant 10
# solution ['dcapfal', 'mngcnaa', 'adgitab', 'despaci', 'iabsera', 'dcapfal', 'anoelon']
# fitness 8
# ant 11
# solution ['eogaalf', 'haidema', 'despaci', 'haidema', 'adgitab', 'mngcnaa', 'iobaggg']
# fitness 7
# ant 12
# solution ['mngcnaa', 'adgitab', 'haidema', 'eogaalf', 'analfab', 'iobaggg', 'dcapfal']
# fitness 6
# ant 13
# solution ['adgitab', 'despaci', 'mngcnaa', 'anoelon', 'eogaalf', 'dcapfal', 'haidema']
# fitness 6
# ----------------------------------------------------------------------------------------------------
# ant 0
# solution ['haidema', 'anoelon', 'adgitab', 'dcapfal', 'anoelon', 'dcapfal', 'anacond']
# fitness 8
# ant 1
# solution ['anacond', 'haidema', 'adgitab', 'mngcnaa', 'haidema', 'eogaalf', 'iabsera']
# fitness 7
# ant 2
# solution ['iobaggg', 'adgitab', 'anoelon', 'mngcnaa', 'eogaalf', 'haidema', 'despaci']
# fitness 6
# ant 3
# solution ['despaci', 'adgitab', 'anacond', 'haidema', 'despaci', 'mngcnaa', 'eogaalf']
# fitness 7
# ant 4
# solution ['elefant', 'haidema', 'haidema', 'eogaalf', 'adgitab', 'haidema', 'mngcnaa']
# fitness 8
# ant 5
# solution ['moralaa', 'haidema', 'anacond', 'adgitab', 'anacond', 'dcapfal', 'iobaggg']
# fitness 7
# ant 6
# solution ['analfab', 'haidema', 'analfab', 'haidema', 'anoelon', 'analfab', 'adgitab']
# fitness 9
# ant 7
# solution ['haidema', 'adgitab', 'mngcnaa', 'eogaalf', 'dcapfal', 'anacond', 'despaci']
# fitness 6
# ant 8
# solution ['anoelon', 'adgitab', 'mngcnaa', 'haidema', 'moralaa', 'adgitab', 'anacond']
# fitness 7
# ant 9
# solution ['iabsera', 'adgitab', 'iobaggg', 'iabsera', 'mngcnaa', 'analfab', 'haidema']
# fitness 7
# ant 10
# solution ['dcapfal', 'haidema', 'mngcnaa', 'analfab', 'elefant', 'dcapfal', 'iabsera']
# fitness 7
# ant 11
# solution ['eogaalf', 'anacond', 'adgitab', 'mngcnaa', 'haidema', 'dcapfal', 'iobaggg']
# fitness 6
# ant 12
# solution ['mngcnaa', 'haidema', 'adgitab', 'mngcnaa', 'haidema', 'despaci', 'anacond']
# fitness 8
# ant 13
# solution ['adgitab', 'dcapfal', 'moralaa', 'haidema', 'mngcnaa', 'eogaalf', 'haidema']
# fitness 7
# ----------------------------------------------------------------------------------------------------
# ant 0
# solution ['haidema', 'adgitab', 'mngcnaa', 'haidema', 'eogaalf', 'adgitab', 'anoelon']
# fitness 8
# ant 1
# solution ['anacond', 'iabsera', 'anoelon', 'haidema', 'haidema', 'elefant', 'moralaa']
# fitness 7
# ant 2
# solution ['iobaggg', 'adgitab', 'mngcnaa', 'elefant', 'analfab', 'anacond', 'haidema']
# fitness 6
# ant 3
# solution ['despaci', 'iobaggg', 'dcapfal', 'haidema', 'anoelon', 'adgitab', 'moralaa']
# fitness 6
# ant 4
# solution ['elefant', 'adgitab', 'mngcnaa', 'haidema', 'elefant', 'haidema', 'dcapfal']
# fitness 8
# ant 5
# solution ['moralaa', 'elefant', 'anoelon', 'despaci', 'adgitab', 'analfab', 'haidema']
# fitness 6
# ant 6
# solution ['analfab', 'mngcnaa', 'iabsera', 'elefant', 'moralaa', 'iabsera', 'anoelon']
# fitness 8
# ant 7
# solution ['haidema', 'despaci', 'adgitab', 'elefant', 'moralaa', 'despaci', 'eogaalf']
# fitness 7
# ant 8
# solution ['anoelon', 'iobaggg', 'adgitab', 'mngcnaa', 'haidema', 'anacond', 'haidema']
# fitness 7
# ant 9
# solution ['iabsera', 'mngcnaa', 'haidema', 'moralaa', 'adgitab', 'mngcnaa', 'eogaalf']
# fitness 7
# ant 10
# solution ['dcapfal', 'haidema', 'adgitab', 'iobaggg', 'mngcnaa', 'eogaalf', 'iabsera']
# fitness 6
# ant 11
# solution ['eogaalf', 'haidema', 'haidema', 'anacond', 'adgitab', 'mngcnaa', 'despaci']
# fitness 7
# ant 12
# solution ['mngcnaa', 'adgitab', 'haidema', 'iabsera', 'anacond', 'haidema', 'eogaalf']
# fitness 7
# ant 13
# solution ['adgitab', 'haidema', 'iobaggg', 'anoelon', 'mngcnaa', 'despaci', 'anacond']
# fitness 6
# ----------------------------------------------------------------------------------------------------
# ant 0
# solution ['haidema', 'adgitab', 'mngcnaa', 'eogaalf', 'adgitab', 'anacond', 'mngcnaa']
# fitness 8
# ant 1
# solution ['anacond', 'dcapfal', 'haidema', 'adgitab', 'elefant', 'mngcnaa', 'iabsera']
# fitness 6
# ant 2
# solution ['iobaggg', 'adgitab', 'mngcnaa', 'haidema', 'eogaalf', 'dcapfal', 'anacond']
# fitness 6
# ant 3
# solution ['despaci', 'adgitab', 'analfab', 'iabsera', 'haidema', 'eogaalf', 'haidema']
# fitness 7
# ant 4
# solution ['elefant', 'iabsera', 'anoelon', 'adgitab', 'moralaa', 'anoelon', 'mngcnaa']
# fitness 8
# ant 5
# solution ['moralaa', 'haidema', 'iabsera', 'dcapfal', 'anacond', 'anoelon', 'mngcnaa']
# fitness 6
# ant 6
# solution ['analfab', 'iabsera', 'haidema', 'iabsera', 'despaci', 'anacond', 'adgitab']
# fitness 7
# ant 7
# solution ['haidema', 'dcapfal', 'anoelon', 'adgitab', 'eogaalf', 'adgitab', 'anacond']
# fitness 7
# ant 8
# solution ['anoelon', 'iobaggg', 'adgitab', 'mngcnaa', 'dcapfal', 'eogaalf', 'haidema']
# fitness 6
# ant 9
# solution ['iabsera', 'dcapfal', 'haidema', 'elefant', 'adgitab', 'anoelon', 'haidema']
# fitness 7
# ant 10
# solution ['dcapfal', 'iobaggg', 'adgitab', 'mngcnaa', 'haidema', 'dcapfal', 'haidema']
# fitness 8
# ant 11
# solution ['eogaalf', 'adgitab', 'elefant', 'haidema', 'mngcnaa', 'elefant', 'haidema']
# fitness 8
# ant 12
# solution ['mngcnaa', 'adgitab', 'eogaalf', 'analfab', 'despaci', 'analfab', 'haidema']
# fitness 7
# ant 13
# solution ['adgitab', 'analfab', 'haidema', 'iabsera', 'iobaggg', 'moralaa', 'haidema']
# fitness 7
# ----------------------------------------------------------------------------------------------------
# ant 0
# solution ['haidema', 'adgitab', 'elefant', 'mngcnaa', 'eogaalf', 'dcapfal', 'anacond']
# fitness 6
# ant 1
# solution ['anacond', 'eogaalf', 'iabsera', 'dcapfal', 'moralaa', 'anacond', 'adgitab']
# fitness 8
# ant 2
# solution ['iobaggg', 'haidema', 'adgitab', 'mngcnaa', 'eogaalf', 'despaci', 'dcapfal']
# fitness 6
# ant 3
# solution ['despaci', 'mngcnaa', 'despaci', 'iobaggg', 'anacond', 'elefant', 'haidema']
# fitness 7
# ant 4
# solution ['elefant', 'anacond', 'anoelon', 'haidema', 'adgitab', 'despaci', 'iobaggg']
# fitness 6
# ant 5
# solution ['moralaa', 'anoelon', 'elefant', 'haidema', 'adgitab', 'mngcnaa', 'eogaalf']
# fitness 6
# ant 6
# solution ['analfab', 'mngcnaa', 'analfab', 'anoelon', 'mngcnaa', 'haidema', 'eogaalf']
# fitness 8
# ant 7
# solution ['haidema', 'adgitab', 'mngcnaa', 'eogaalf', 'despaci', 'dcapfal', 'iobaggg']
# fitness 6
# ant 8
# solution ['anoelon', 'eogaalf', 'haidema', 'mngcnaa', 'adgitab', 'iabsera', 'anacond']
# fitness 6
# ant 9
# solution ['iabsera', 'adgitab', 'mngcnaa', 'despaci', 'anacond', 'haidema', 'anoelon']
# fitness 6
# ant 10
# solution ['dcapfal', 'haidema', 'anacond', 'anoelon', 'anacond', 'adgitab', 'analfab']
# fitness 7
# ant 11
# solution ['eogaalf', 'analfab', 'haidema', 'adgitab', 'haidema', 'anoelon', 'mngcnaa']
# fitness 7
# ant 12
# solution ['mngcnaa', 'haidema', 'adgitab', 'despaci', 'anacond', 'eogaalf', 'dcapfal']
# fitness 6
# ant 13
# solution ['adgitab', 'anacond', 'adgitab', 'anoelon', 'iobaggg', 'mngcnaa', 'anoelon']
# fitness 9
# ----------------------------------------------------------------------------------------------------
# ant 0
# solution ['haidema', 'adgitab', 'mngcnaa', 'eogaalf', 'haidema', 'dcapfal', 'anacond']
# fitness 7
# ant 1
# solution ['anacond', 'adgitab', 'iabsera', 'mngcnaa', 'haidema', 'eogaalf', 'analfab']
# fitness 6
# ant 2
# solution ['iobaggg', 'mngcnaa', 'elefant', 'dcapfal', 'despaci', 'moralaa', 'anacond']
# fitness 7
# ant 3
# solution ['despaci', 'iabsera', 'haidema', 'adgitab', 'mngcnaa', 'eogaalf', 'adgitab']
# fitness 7
# ant 4
# solution ['elefant', 'moralaa', 'haidema', 'adgitab', 'dcapfal', 'anacond', 'iobaggg']
# fitness 6
# ant 5
# solution ['moralaa', 'haidema', 'adgitab', 'analfab', 'mngcnaa', 'eogaalf', 'mngcnaa']
# fitness 7
# ant 6
# solution ['analfab', 'adgitab', 'iabsera', 'mngcnaa', 'adgitab', 'anacond', 'haidema']
# fitness 7
# ant 7
# solution ['haidema', 'dcapfal', 'iabsera', 'adgitab', 'anoelon', 'adgitab', 'mngcnaa']
# fitness 7
# ant 8
# solution ['anoelon', 'adgitab', 'elefant', 'mngcnaa', 'eogaalf', 'iobaggg', 'despaci']
# fitness 7
# ant 9
# solution ['iabsera', 'adgitab', 'moralaa', 'elefant', 'moralaa', 'despaci', 'haidema']
# fitness 7
# ant 10
# solution ['dcapfal', 'haidema', 'adgitab', 'mngcnaa', 'eogaalf', 'anacond', 'dcapfal']
# fitness 7
# ant 11
# solution ['eogaalf', 'haidema', 'eogaalf', 'mngcnaa', 'adgitab', 'anacond', 'haidema']
# fitness 8
# ant 12
# solution ['mngcnaa', 'adgitab', 'haidema', 'adgitab', 'dcapfal', 'moralaa', 'mngcnaa']
# fitness 8
# ant 13
# solution ['adgitab', 'mngcnaa', 'eogaalf', 'haidema', 'analfab', 'elefant', 'anoelon']
# fitness 6
# ----------------------------------------------------------------------------------------------------
# ant 0
# solution ['haidema', 'iabsera', 'adgitab', 'dcapfal', 'moralaa', 'haidema', 'mngcnaa']
# fitness 7
# ant 1
# solution ['anacond', 'adgitab', 'mngcnaa', 'elefant', 'haidema', 'eogaalf', 'iobaggg']
# fitness 6
# ant 2
# solution ['iobaggg', 'adgitab', 'analfab', 'haidema', 'elefant', 'mngcnaa', 'eogaalf']
# fitness 6
# ant 3
# solution ['despaci', 'iabsera', 'adgitab', 'despaci', 'eogaalf', 'mngcnaa', 'moralaa']
# fitness 8
# ant 4
# solution ['elefant', 'dcapfal', 'iobaggg', 'eogaalf', 'haidema', 'adgitab', 'iobaggg']
# fitness 7
# ant 5
# solution ['moralaa', 'haidema', 'adgitab', 'haidema', 'dcapfal', 'anacond', 'haidema']
# fitness 8
# ant 6
# solution ['analfab', 'haidema', 'eogaalf', 'iobaggg', 'dcapfal', 'anacond', 'adgitab']
# fitness 6
# ant 7
# solution ['haidema', 'iobaggg', 'anoelon', 'adgitab', 'mngcnaa', 'anacond', 'haidema']
# fitness 7
# ant 8
# solution ['anoelon', 'adgitab', 'mngcnaa', 'haidema', 'eogaalf', 'dcapfal', 'anacond']
# fitness 6
# ant 9
# solution ['iabsera', 'adgitab', 'mngcnaa', 'haidema', 'eogaalf', 'dcapfal', 'iabsera']
# fitness 7
# ant 10
# solution ['dcapfal', 'analfab', 'anacond', 'adgitab', 'moralaa', 'iabsera', 'adgitab']
# fitness 8
# ant 11
# solution ['eogaalf', 'haidema', 'adgitab', 'moralaa', 'haidema', 'mngcnaa', 'adgitab']
# fitness 8
# ant 12
# solution ['mngcnaa', 'anacond', 'adgitab', 'anoelon', 'dcapfal', 'iabsera', 'eogaalf']
# fitness 7
# ant 13
# solution ['adgitab', 'anoelon', 'iobaggg', 'anoelon', 'mngcnaa', 'haidema', 'eogaalf']
# fitness 7
# ----------------------------------------------------------------------------------------------------
# ant 0
# solution ['haidema', 'adgitab', 'mngcnaa', 'eogaalf', 'haidema', 'dcapfal', 'anacond']
# fitness 7
# ant 1
# solution ['anacond', 'iobaggg', 'anoelon', 'adgitab', 'elefant', 'analfab', 'elefant']
# fitness 8
# ant 2
# solution ['iobaggg', 'elefant', 'mngcnaa', 'iobaggg', 'adgitab', 'analfab', 'anoelon']
# fitness 8
# ant 3
# solution ['despaci', 'adgitab', 'eogaalf', 'iabsera', 'anacond', 'eogaalf', 'moralaa']
# fitness 8
# ant 4
# solution ['elefant', 'adgitab', 'mngcnaa', 'anacond', 'adgitab', 'elefant', 'haidema']
# fitness 8
# ant 5
# solution ['moralaa', 'haidema', 'haidema', 'adgitab', 'mngcnaa', 'eogaalf', 'haidema']
# fitness 8
# ant 6
# solution ['analfab', 'moralaa', 'haidema', 'eogaalf', 'haidema', 'adgitab', 'anoelon']
# fitness 7
# ant 7
# solution ['haidema', 'anoelon', 'moralaa', 'anacond', 'adgitab', 'haidema', 'iobaggg']
# fitness 7
# ant 8
# solution ['anoelon', 'adgitab', 'mngcnaa', 'analfab', 'dcapfal', 'haidema', 'eogaalf']
# fitness 6
# ant 9
# solution ['iabsera', 'adgitab', 'mngcnaa', 'analfab', 'haidema', 'iobaggg', 'eogaalf']
# fitness 6
# ant 10
# solution ['dcapfal', 'haidema', 'adgitab', 'moralaa', 'anoelon', 'dcapfal', 'anoelon']
# fitness 8
# ant 11
# solution ['eogaalf', 'iabsera', 'eogaalf', 'haidema', 'adgitab', 'mngcnaa', 'anacond']
# fitness 7
# ant 12
# solution ['mngcnaa', 'dcapfal', 'haidema', 'eogaalf', 'adgitab', 'anoelon', 'anacond']
# fitness 6
# ant 13
# solution ['adgitab', 'mngcnaa', 'anoelon', 'dcapfal', 'adgitab', 'haidema', 'elefant']
# fitness 7
# ----------------------------------------------------------------------------------------------------
# ant 0
# solution ['haidema', 'anoelon', 'adgitab', 'analfab', 'dcapfal', 'anacond', 'dcapfal']
# fitness 7
# ant 1
# solution ['anacond', 'adgitab', 'haidema', 'dcapfal', 'despaci', 'eogaalf', 'mngcnaa']
# fitness 6
# ant 2
# solution ['iobaggg', 'adgitab', 'anacond', 'analfab', 'mngcnaa', 'haidema', 'adgitab']
# fitness 7
# ant 3
# solution ['despaci', 'elefant', 'haidema', 'adgitab', 'mngcnaa', 'haidema', 'eogaalf']
# fitness 7
# ant 4
# solution ['elefant', 'iobaggg', 'adgitab', 'mngcnaa', 'despaci', 'haidema', 'moralaa']
# fitness 6
# ant 5
# solution ['moralaa', 'haidema', 'adgitab', 'moralaa', 'anacond', 'despaci', 'mngcnaa']
# fitness 7
# ant 6
# solution ['analfab', 'adgitab', 'mngcnaa', 'haidema', 'eogaalf', 'dcapfal', 'haidema']
# fitness 7
# ant 7
# solution ['haidema', 'anoelon', 'adgitab', 'eogaalf', 'moralaa', 'mngcnaa', 'eogaalf']
# fitness 7
# ant 8
# solution ['anoelon', 'haidema', 'moralaa', 'adgitab', 'mngcnaa', 'eogaalf', 'adgitab']
# fitness 7
# ant 9
# solution ['iabsera', 'iobaggg', 'anoelon', 'moralaa', 'haidema', 'adgitab', 'mngcnaa']
# fitness 6
# ant 10
# solution ['dcapfal', 'haidema', 'elefant', 'despaci', 'adgitab', 'anoelon', 'adgitab']
# fitness 7
# ant 11
# solution ['eogaalf', 'haidema', 'adgitab', 'analfab', 'mngcnaa', 'dcapfal', 'anacond']
# fitness 6
# ant 12
# solution ['mngcnaa', 'despaci', 'adgitab', 'anacond', 'despaci', 'haidema', 'analfab']
# fitness 7
# ant 13
# solution ['adgitab', 'mngcnaa', 'iobaggg', 'iabsera', 'elefant', 'haidema', 'adgitab']
# fitness 7
# ----------------------------------------------------------------------------------------------------
# ant 0
# ...
# fitness 7
# ant 11
# solution ['eogaalf', 'haidema', 'elefant', 'adgitab', 'mngcnaa', 'anacond', 'iobaggg']
# fitness 6
# ant 12
# solution ['mngcnaa', 'adgitab', 'haidema', 'eogaalf', 'dcapfal', 'anacond', 'iabsera']
# fitness 6
# ant 13
# solution ['adgitab', 'anoelon', 'moralaa', 'haidema', 'mngcnaa', 'eogaalf', 'adgitab']
# fitness 7
# ----------------------------------------------------------------------------------------------------
# ant 0
# solution ['haidema', 'anacond', 'adgitab', 'analfab', 'moralaa', 'elefant', 'anoelon']
# fitness 6
# ant 1
# solution ['anacond', 'iabsera', 'dcapfal', 'haidema', 'mngcnaa', 'adgitab', 'anacond']
# fitness 7
# ant 2
# solution ['iobaggg', 'adgitab', 'despaci', 'mngcnaa', 'haidema', 'eogaalf', 'anacond']
# fitness 6
# ant 3
# solution ['despaci', 'moralaa', 'haidema', 'mngcnaa', 'adgitab', 'mngcnaa', 'analfab']
# fitness 7
# ant 4
# solution ['elefant', 'adgitab', 'iabsera', 'mngcnaa', 'eogaalf', 'haidema', 'dcapfal']
# fitness 6
# ant 5
# solution ['moralaa', 'haidema', 'adgitab', 'eogaalf', 'despaci', 'mngcnaa', 'anoelon']
# fitness 6
# ant 6
# solution ['analfab', 'haidema', 'dcapfal', 'haidema', 'adgitab', 'despaci', 'mngcnaa']
# fitness 7
# ant 7
# solution ['haidema', 'adgitab', 'despaci', 'moralaa', 'analfab', 'mngcnaa', 'haidema']
# fitness 7
# ant 8
# solution ['anoelon', 'mngcnaa', 'despaci', 'adgitab', 'haidema', 'dcapfal', 'elefant']
# fitness 6
# ant 9
# solution ['iabsera', 'adgitab', 'dcapfal', 'anoelon', 'mngcnaa', 'iobaggg', 'anacond']
# fitness 7
# ant 10
# solution ['dcapfal', 'haidema', 'adgitab', 'iabsera', 'eogaalf', 'moralaa', 'anacond']
# fitness 6
# ant 11
# solution ['eogaalf', 'haidema', 'moralaa', 'anoelon', 'eogaalf', 'adgitab', 'anacond']
# fitness 7
# ant 12
# solution ['mngcnaa', 'adgitab', 'haidema', 'moralaa', 'dcapfal', 'moralaa', 'anacond']
# fitness 7
# ant 13
# solution ['adgitab', 'eogaalf', 'mngcnaa', 'iabsera', 'mngcnaa', 'iabsera', 'haidema']
# fitness 8
# ----------------------------------------------------------------------------------------------------
# ant 0
# solution ['haidema', 'iabsera', 'despaci', 'elefant', 'eogaalf', 'analfab', 'haidema']
# fitness 7
# ant 1
# solution ['anacond', 'iobaggg', 'moralaa', 'analfab', 'haidema', 'despaci', 'anacond']
# fitness 7
# ant 2
# solution ['iobaggg', 'adgitab', 'mngcnaa', 'eogaalf', 'haidema', 'dcapfal', 'mngcnaa']
# fitness 7
# ant 3
# solution ['despaci', 'adgitab', 'mngcnaa', 'eogaalf', 'anoelon', 'haidema', 'anacond']
# fitness 6
# ant 4
# solution ['elefant', 'haidema', 'adgitab', 'mngcnaa', 'iobaggg', 'moralaa', 'anacond']
# fitness 6
# ant 5
# solution ['moralaa', 'despaci', 'iobaggg', 'anoelon', 'haidema', 'despaci', 'adgitab']
# fitness 7
# ant 6
# solution ['analfab', 'adgitab', 'analfab', 'haidema', 'mngcnaa', 'iabsera', 'anacond']
# fitness 7
# ant 7
# solution ['haidema', 'anacond', 'elefant', 'haidema', 'moralaa', 'adgitab', 'moralaa']
# fitness 8
# ant 8
# solution ['anoelon', 'adgitab', 'mngcnaa', 'eogaalf', 'haidema', 'mngcnaa', 'anacond']
# fitness 7
# ant 9
# solution ['iabsera', 'adgitab', 'mngcnaa', 'eogaalf', 'dcapfal', 'despaci', 'haidema']
# fitness 6
# ant 10
# solution ['dcapfal', 'iabsera', 'adgitab', 'eogaalf', 'moralaa', 'haidema', 'mngcnaa']
# fitness 6
# ant 11
# solution ['eogaalf', 'haidema', 'adgitab', 'dcapfal', 'adgitab', 'mngcnaa', 'adgitab']
# fitness 8
# ant 12
# solution ['mngcnaa', 'moralaa', 'haidema', 'haidema', 'eogaalf', 'anoelon', 'haidema']
# fitness 8
# ant 13
# solution ['adgitab', 'iobaggg', 'anacond', 'iobaggg', 'haidema', 'moralaa', 'mngcnaa']
# fitness 7
# ----------------------------------------------------------------------------------------------------
# ant 0
# solution ['haidema', 'moralaa', 'iobaggg', 'adgitab', 'haidema', 'elefant', 'analfab']
# fitness 7
# ant 1
# solution ['anacond', 'adgitab', 'haidema', 'mngcnaa', 'eogaalf', 'dcapfal', 'iabsera']
# fitness 6
# ant 2
# solution ['iobaggg', 'haidema', 'anacond', 'adgitab', 'anoelon', 'haidema', 'anacond']
# fitness 8
# ant 3
# solution ['despaci', 'eogaalf', 'haidema', 'eogaalf', 'mngcnaa', 'iabsera', 'eogaalf']
# fitness 8
# ant 4
# solution ['elefant', 'haidema', 'adgitab', 'mngcnaa', 'eogaalf', 'despaci', 'eogaalf']
# fitness 7
# ant 5
# solution ['moralaa', 'iobaggg', 'analfab', 'despaci', 'haidema', 'adgitab', 'mngcnaa']
# fitness 6
# ant 6
# solution ['analfab', 'anacond', 'iabsera', 'haidema', 'anacond', 'elefant', 'despaci']
# fitness 7
# ant 7
# solution ['haidema', 'elefant', 'despaci', 'haidema', 'haidema', 'iobaggg', 'eogaalf']
# fitness 8
# ant 8
# solution ['anoelon', 'dcapfal', 'anacond', 'adgitab', 'analfab', 'elefant', 'mngcnaa']
# fitness 7
# ant 9
# solution ['iabsera', 'adgitab', 'haidema', 'eogaalf', 'haidema', 'mngcnaa', 'haidema']
# fitness 8
# ant 10
# solution ['dcapfal', 'elefant', 'adgitab', 'eogaalf', 'despaci', 'mngcnaa', 'moralaa']
# fitness 7
# ant 11
# solution ['eogaalf', 'elefant', 'adgitab', 'mngcnaa', 'iabsera', 'haidema', 'eogaalf']
# fitness 7
# ant 12
# solution ['mngcnaa', 'haidema', 'adgitab', 'despaci', 'iabsera', 'elefant', 'eogaalf']
# fitness 6
# ant 13
# solution ['adgitab', 'anoelon', 'mngcnaa', 'eogaalf', 'haidema', 'despaci', 'dcapfal']
# fitness 6
# ----------------------------------------------------------------------------------------------------
# ant 0
# solution ['haidema', 'anoelon', 'adgitab', 'moralaa', 'anacond', 'mngcnaa', 'analfab']
# fitness 6
# ant 1
# solution ['anacond', 'mngcnaa', 'elefant', 'adgitab', 'haidema', 'anacond', 'iabsera']
# fitness 7
# ant 2
# solution ['iobaggg', 'adgitab', 'mngcnaa', 'anacond', 'adgitab', 'haidema', 'iobaggg']
# fitness 8
# ant 3
# solution ['despaci', 'elefant', 'adgitab', 'mngcnaa', 'eogaalf', 'iabsera', 'moralaa']
# fitness 7
# ant 4
# solution ['elefant', 'adgitab', 'mngcnaa', 'iobaggg', 'analfab', 'adgitab', 'haidema']
# fitness 7
# ant 5
# solution ['moralaa', 'haidema', 'eogaalf', 'adgitab', 'mngcnaa', 'anacond', 'dcapfal']
# fitness 6
# ant 6
# solution ['analfab', 'haidema', 'adgitab', 'mngcnaa', 'moralaa', 'anacond', 'eogaalf']
# fitness 6
# ant 7
# solution ['haidema', 'anacond', 'mngcnaa', 'adgitab', 'iobaggg', 'mngcnaa', 'iobaggg']
# fitness 8
# ant 8
# solution ['anoelon', 'iobaggg', 'anacond', 'elefant', 'moralaa', 'iabsera', 'mngcnaa']
# fitness 7
# ant 9
# solution ['iabsera', 'adgitab', 'mngcnaa', 'eogaalf', 'haidema', 'eogaalf', 'anacond']
# fitness 7
# ant 10
# solution ['dcapfal', 'despaci', 'analfab', 'haidema', 'iobaggg', 'adgitab', 'mngcnaa']
# fitness 6
# ant 11
# solution ['eogaalf', 'moralaa', 'haidema', 'despaci', 'adgitab', 'mngcnaa', 'anacond']
# fitness 6
# ant 12
# solution ['mngcnaa', 'adgitab', 'haidema', 'anoelon', 'eogaalf', 'dcapfal', 'anoelon']
# fitness 7
# ant 13
# solution ['adgitab', 'anacond', 'despaci', 'analfab', 'mngcnaa', 'eogaalf', 'iabsera']
# fitness 7
# ----------------------------------------------------------------------------------------------------
# ant 0
# solution ['haidema', 'iobaggg', 'haidema', 'adgitab', 'mngcnaa', 'iobaggg', 'eogaalf']
# fitness 8
# ant 1
# solution ['anacond', 'adgitab', 'despaci', 'mngcnaa', 'anoelon', 'haidema', 'anacond']
# fitness 7
# ant 2
# solution ['iobaggg', 'adgitab', 'mngcnaa', 'eogaalf', 'haidema', 'adgitab', 'anacond']
# fitness 7
# ant 3
# solution ['despaci', 'adgitab', 'mngcnaa', 'iobaggg', 'mngcnaa', 'eogaalf', 'dcapfal']
# fitness 8
# ant 4
# solution ['elefant', 'despaci', 'anoelon', 'adgitab', 'mngcnaa', 'eogaalf', 'haidema']
# fitness 6
# ant 5
# solution ['moralaa', 'eogaalf', 'haidema', 'iobaggg', 'dcapfal', 'anacond', 'dcapfal']
# fitness 7
# ant 6
# solution ['analfab', 'despaci', 'mngcnaa', 'despaci', 'adgitab', 'analfab', 'haidema']
# fitness 8
# ant 7
# solution ['haidema', 'adgitab', 'eogaalf', 'moralaa', 'anacond', 'mngcnaa', 'haidema']
# fitness 7
# ant 8
# solution ['anoelon', 'adgitab', 'despaci', 'haidema', 'haidema', 'eogaalf', 'mngcnaa']
# fitness 7
# ant 9
# solution ['iabsera', 'analfab', 'anoelon', 'elefant', 'iabsera', 'dcapfal', 'haidema']
# fitness 7
# ant 10
# solution ['dcapfal', 'eogaalf', 'haidema', 'adgitab', 'mngcnaa', 'iabsera', 'mngcnaa']
# fitness 7
# ant 11
# solution ['eogaalf', 'haidema', 'eogaalf', 'anoelon', 'adgitab', 'despaci', 'mngcnaa']
# fitness 7
# ant 12
# solution ['mngcnaa', 'elefant', 'anoelon', 'mngcnaa', 'adgitab', 'haidema', 'eogaalf']
# fitness 7
# ant 13
# solution ['adgitab', 'haidema', 'despaci', 'mngcnaa', 'iabsera', 'haidema', 'eogaalf']
# fitness 7
# ----------------------------------------------------------------------------------------------------
# ant 0
# solution ['haidema', 'mngcnaa', 'adgitab', 'anacond', 'eogaalf', 'adgitab', 'iobaggg']
# fitness 7
# ant 1
# solution ['anacond', 'adgitab', 'mngcnaa', 'elefant', 'dcapfal', 'eogaalf', 'haidema']
# fitness 6
# ant 2
# solution ['iobaggg', 'despaci', 'elefant', 'despaci', 'iobaggg', 'adgitab', 'mngcnaa']
# fitness 9
# ant 3
# solution ['despaci', 'adgitab', 'mngcnaa', 'eogaalf', 'haidema', 'adgitab', 'moralaa']
# fitness 7
# ant 4
# solution ['elefant', 'anoelon', 'elefant', 'haidema', 'adgitab', 'eogaalf', 'mngcnaa']
# fitness 7
# ant 5
# solution ['moralaa', 'despaci', 'elefant', 'adgitab', 'mngcnaa', 'adgitab', 'haidema']
# fitness 7
# ant 6
# solution ['analfab', 'haidema', 'anoelon', 'adgitab', 'mngcnaa', 'eogaalf', 'mngcnaa']
# fitness 7
# ant 7
# solution ['haidema', 'adgitab', 'dcapfal', 'despaci', 'mngcnaa', 'haidema', 'dcapfal']
# fitness 8
# ant 8
# solution ['anoelon', 'haidema', 'adgitab', 'mngcnaa', 'eogaalf', 'haidema', 'adgitab']
# fitness 8
# ant 9
# solution ['iabsera', 'adgitab', 'mngcnaa', 'iobaggg', 'dcapfal', 'elefant', 'anacond']
# fitness 7
# ant 10
# solution ['dcapfal', 'eogaalf', 'haidema', 'adgitab', 'mngcnaa', 'anacond', 'iabsera']
# fitness 6
# ant 11
# solution ['eogaalf', 'haidema', 'adgitab', 'mngcnaa', 'anacond', 'haidema', 'iabsera']
# fitness 7
# ant 12
# solution ['mngcnaa', 'adgitab', 'elefant', 'dcapfal', 'eogaalf', 'haidema', 'anacond']
# fitness 6
# ant 13
# solution ['adgitab', 'mngcnaa', 'moralaa', 'haidema', 'eogaalf', 'haidema', 'elefant']
# fitness 7
# ----------------------------------------------------------------------------------------------------
# ant 0
# solution ['haidema', 'elefant', 'adgitab', 'mngcnaa', 'adgitab', 'haidema', 'eogaalf']
# fitness 8
# ant 1
# solution ['anacond', 'adgitab', 'elefant', 'dcapfal', 'iobaggg', 'haidema', 'iabsera']
# fitness 6
# ant 2
# solution ['iobaggg', 'anacond', 'mngcnaa', 'moralaa', 'mngcnaa', 'adgitab', 'haidema']
# fitness 7
# ant 3
# solution ['despaci', 'dcapfal', 'elefant', 'eogaalf', 'haidema', 'analfab', 'anacond']
# fitness 6
# ant 4
# solution ['elefant', 'iobaggg', 'haidema', 'adgitab', 'haidema', 'mngcnaa', 'eogaalf']
# fitness 7
# ant 5
# solution ['moralaa', 'haidema', 'adgitab', 'mngcnaa', 'eogaalf', 'dcapfal', 'adgitab']
# fitness 7
# ant 6
# solution ['analfab', 'dcapfal', 'haidema', 'iabsera', 'adgitab', 'haidema', 'analfab']
# fitness 8
# ant 7
# solution ['haidema', 'adgitab', 'iobaggg', 'despaci', 'anacond', 'haidema', 'iobaggg']
# fitness 8
# ant 8
# solution ['anoelon', 'eogaalf', 'iabsera', 'analfab', 'anacond', 'adgitab', 'despaci']
# fitness 7
# ant 9
# solution ['iabsera', 'moralaa', 'analfab', 'iobaggg', 'haidema', 'anoelon', 'adgitab']
# fitness 6
# ant 10
# solution ['dcapfal', 'haidema', 'elefant', 'adgitab', 'eogaalf', 'iabsera', 'mngcnaa']
# fitness 6
# ant 11
# solution ['eogaalf', 'mngcnaa', 'iobaggg', 'haidema', 'iabsera', 'adgitab', 'elefant']
# fitness 6
# ant 12
# solution ['mngcnaa', 'moralaa', 'haidema', 'adgitab', 'anacond', 'eogaalf', 'iobaggg']
# fitness 6
# ant 13
# solution ['adgitab', 'dcapfal', 'haidema', 'mngcnaa', 'eogaalf', 'anacond', 'elefant']
# fitness 6
# ----------------------------------------------------------------------------------------------------
# ant 0
# solution ['haidema', 'despaci', 'dcapfal', 'anacond', 'adgitab', 'haidema', 'mngcnaa']
# fitness 7
# ant 1
# solution ['anacond', 'adgitab', 'anoelon', 'mngcnaa', 'eogaalf', 'haidema', 'dcapfal']
# fitness 6
# ant 2
# solution ['iobaggg', 'eogaalf', 'mngcnaa', 'adgitab', 'anoelon', 'haidema', 'dcapfal']
# fitness 6
# ant 3
# solution ['despaci', 'adgitab', 'mngcnaa', 'eogaalf', 'haidema', 'dcapfal', 'haidema']
# fitness 7
# ant 4
# solution ['elefant', 'adgitab', 'anacond', 'elefant', 'mngcnaa', 'anacond', 'haidema']
# fitness 8
# ant 5
# solution ['moralaa', 'anacond', 'adgitab', 'iabsera', 'anacond', 'mngcnaa', 'eogaalf']
# fitness 8
# ant 6
# solution ['analfab', 'haidema', 'dcapfal', 'moralaa', 'adgitab', 'moralaa', 'anacond']
# fitness 7
# ant 7
# solution ['haidema', 'adgitab', 'mngcnaa', 'haidema', 'eogaalf', 'dcapfal', 'anacond']
# fitness 7
# ant 8
# solution ['anoelon', 'iabsera', 'adgitab', 'anacond', 'mngcnaa', 'eogaalf', 'anoelon']
# fitness 8
# ant 9
# solution ['iabsera', 'adgitab', 'iabsera', 'moralaa', 'dcapfal', 'haidema', 'mngcnaa']
# fitness 7
# ant 10
# solution ['dcapfal', 'haidema', 'adgitab', 'moralaa', 'mngcnaa', 'anacond', 'eogaalf']
# fitness 6
# ant 11
# solution ['eogaalf', 'haidema', 'adgitab', 'iabsera', 'mngcnaa', 'haidema', 'despaci']
# fitness 7
# ant 12
# solution ['mngcnaa', 'adgitab', 'haidema', 'eogaalf', 'iobaggg', 'dcapfal', 'haidema']
# fitness 7
# ant 13
# solution ['adgitab', 'mngcnaa', 'anacond', 'haidema', 'iobaggg', 'adgitab', 'despaci']
# fitness 7
# ----------------------------------------------------------------------------------------------------
# ant 0
# solution ['haidema', 'adgitab', 'anoelon', 'analfab', 'dcapfal', 'haidema', 'analfab']
# fitness 8
# ant 1
# solution ['anacond', 'moralaa', 'haidema', 'adgitab', 'mngcnaa', 'adgitab', 'eogaalf']
# fitness 7
# ant 2
# solution ['iobaggg', 'analfab', 'haidema', 'anacond', 'haidema', 'eogaalf', 'moralaa']
# fitness 7
# ant 3
# solution ['despaci', 'analfab', 'anacond', 'iobaggg', 'adgitab', 'dcapfal', 'haidema']
# fitness 6
# ant 4
# solution ['elefant', 'analfab', 'elefant', 'anacond', 'adgitab', 'mngcnaa', 'analfab']
# fitness 9
# ant 5
# solution ['moralaa', 'haidema', 'adgitab', 'mngcnaa', 'eogaalf', 'dcapfal', 'iabsera']
# fitness 6
# ant 6
# solution ['analfab', 'mngcnaa', 'adgitab', 'haidema', 'dcapfal', 'eogaalf', 'anacond']
# fitness 6
# ant 7
# solution ['haidema', 'adgitab', 'mngcnaa', 'haidema', 'eogaalf', 'dcapfal', 'iobaggg']
# fitness 7
# ant 8
# solution ['anoelon', 'adgitab', 'elefant', 'mngcnaa', 'eogaalf', 'haidema', 'anacond']
# fitness 6
# ant 9
# solution ['iabsera', 'adgitab', 'eogaalf', 'anacond', 'mngcnaa', 'haidema', 'dcapfal']
# fitness 6
# ant 10
# solution ['dcapfal', 'haidema', 'dcapfal', 'eogaalf', 'haidema', 'adgitab', 'anacond']
# fitness 8
# ant 11
# solution ['eogaalf', 'haidema', 'despaci', 'elefant', 'moralaa', 'anacond', 'adgitab']
# fitness 6
# ant 12
# solution ['mngcnaa', 'adgitab', 'anacond', 'haidema', 'eogaalf', 'analfab', 'iobaggg']
# fitness 6
# ant 13
# solution ['adgitab', 'mngcnaa', 'eogaalf', 'analfab', 'despaci', 'anoelon', 'eogaalf']
# fitness 8
# ----------------------------------------------------------------------------------------------------
# ant 0
# solution ['haidema', 'mngcnaa', 'dcapfal', 'haidema', 'adgitab', 'anoelon', 'eogaalf']
# fitness 7
# ant 1
# solution ['anacond', 'adgitab', 'mngcnaa', 'moralaa', 'haidema', 'eogaalf', 'dcapfal']
# fitness 6
# ant 2
# solution ['iobaggg', 'adgitab', 'mngcnaa', 'eogaalf', 'dcapfal', 'anacond', 'haidema']
# fitness 6
# ant 3
# solution ['despaci', 'adgitab', 'mngcnaa', 'eogaalf', 'iobaggg', 'haidema', 'iobaggg']
# fitness 7
# ant 4
# solution ['elefant', 'adgitab', 'anacond', 'mngcnaa', 'iobaggg', 'analfab', 'haidema']
# fitness 6
# ant 5
# solution ['moralaa', 'adgitab', 'mngcnaa', 'analfab', 'haidema', 'eogaalf', 'elefant']
# fitness 6
# ant 6
# solution ['analfab', 'haidema', 'dcapfal', 'mngcnaa', 'eogaalf', 'mngcnaa', 'eogaalf']
# fitness 8
# ant 7
# solution ['haidema', 'adgitab', 'anoelon', 'adgitab', 'haidema', 'mngcnaa', 'anacond']
# fitness 8
# ant 8
# solution ['anoelon', 'analfab', 'haidema', 'adgitab', 'mngcnaa', 'eogaalf', 'dcapfal']
# fitness 6
# ant 9
# solution ['iabsera', 'adgitab', 'iabsera', 'mngcnaa', 'eogaalf', 'iabsera', 'despaci']
# fitness 9
# ant 10
# solution ['dcapfal', 'analfab', 'adgitab', 'mngcnaa', 'eogaalf', 'elefant', 'mngcnaa']
# fitness 8
# ant 11
# solution ['eogaalf', 'haidema', 'adgitab', 'anoelon', 'iobaggg', 'elefant', 'moralaa']
# fitness 6
# ant 12
# solution ['mngcnaa', 'adgitab', 'iabsera', 'analfab', 'iobaggg', 'despaci', 'anacond']
# fitness 7
# ant 13
# solution ['adgitab', 'haidema', 'haidema', 'mngcnaa', 'despaci', 'analfab', 'moralaa']
# fitness 7
# ----------------------------------------------------------------------------------------------------
# ['anacond', 'adgitab', 'mngcnaa', 'moralaa', 'haidema', 'eogaalf', 'dcapfal'] fitness 6
